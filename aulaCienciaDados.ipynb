# %%
df
# Out:
#          Nome  Idade
# 0       Alice     22
# 1         Bob     20
# 2     Charlie     23
# 3       David     21
# 4        Emma     24
# 5       Frank     20
# 6       Grace     22
# 7       Henry     23
# 8      Isabel     21
# 9        Jack     22
# 10  Katherine     20
# 11        Leo     21
# 12        Mia     24
# 13       Noah     23
# 14     Olivia     22
# 15      Peter     20
# 16      Quinn     21
# 17     Rachel     23
# 18        Sam     22
# 19     Taylor     24
# 20        Uma     20
# 21     Victor     21
# 22      Wendy     22
# 23     Xander     23
# 24       Yara     21
# 25       Zach     20
# 26       Lily     22
# 27      Ethan     23
# 28     Sophia     20
# 29      Jacob     21
# 30        Ava     24
# 31      Mason     22
# 32      Emily     23
# 33       Liam     21
# 34       Aria     20
# 35      Lucas     24
# 36      Chloe     22
# 37      Logan     23
# 38       Ella     21
# 39     Nathan     22
# 40      Grace     23

# %%
import random

mascara = df[df['Idade'] > 21]
mascara2 = df[df['Idade'] <= 21]

amostra = mascara.sample(5)
amostra2 = mascara2.sample(5)

print("Amostra 1:",amostra)
print("Amostra 2:",amostra2)
# Out:
# Amostra 1:        Nome  Idade
# 9      Jack     22
# 2   Charlie     23
# 17   Rachel     23
# 39   Nathan     22
# 4      Emma     24
# Amostra 2:      Nome  Idade
# 3   David     21
# 29  Jacob     21
# 16  Quinn     21
# 38   Ella     21
# 5   Frank     20
